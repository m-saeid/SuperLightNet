# %%
# prompt: connect to drive

from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/SuperLightNet/SuperLiteNet_new/classification_ModelNet40')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !bash run_test.sh
# Out:
# args: Namespace(checkpoint='SLNet_edge0_fps-20250205061809-5539', msg=None, batch_size=16, model='SLNet_edge0_fps', num_classes=40, num_points=1024)
# ==> Using device: cuda
# ==> Preparing data..
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ==> Building model..
# ...

# %%
# Vanilla out: {'loss': 3.136, 'acc': 19.408, 'acc_avg': 11.975, 'time': 27}
# Vanilla out: {'loss': 3.13, 'acc': 19.368, 'acc_avg': 11.95, 'time': 27}
# Vanilla out: {'loss': 3.131, 'acc': 19.611, 'acc_avg': 12.1, 'time': 26}
# Vanilla out: {'loss': 3.132, 'acc': 19.652, 'acc_avg': 12.125, 'time': 25}

# %%
# !bash run_train.sh
# Out:
# args: Namespace(checkpoint='checkpoints/SLNet_edge0_fps-20250205091926-2455', msg=None, batch_size=50, model='SLNet_edge0_fps', epoch=300, num_points=1024, learning_rate=0.1, min_lr=0.005, weight_decay=0.0002, seed=2455, workers=6)
# ==> Building model..
# number of params: 141040
# ==> Preparing data..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-ad8fbeafebfe> in <cell line: 0>()
# ----> 1 get_ipython().system('bash run_train.sh')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# ...
